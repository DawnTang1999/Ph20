# %%
from math import*
import matplotlib.pyplot as plt

# %%
def curves(fx, fy, Ax, Ay, phi, dt, N):
    X = []
    Y = []
    Z = []
    for a in range(N):
        X.append(Ax * cos(2*pi*fx*a*dt))
        Y.append(Ay * sin(2*pi*fy*a*dt + phi))
        Z.append(X[a] + Y[a])
    with open('for_loop_x.txt', 'w') as f1:
        for element in X:
            f1.write("%s\n" % element)
    with open('for_loop_y.txt', 'w') as f2:
        for element in Y:
            f2.write("%s\n" % element)
    with open('for_loop_z.txt', 'w') as f3:
        for element in Z:
            f3.write("%s\n" % element)
    f1.close()
    f2.close()
    f3.close()
    plt.plot(X,Y)
    plt.show()
    plt.plot(Z)
    plt.show()

# %%
curves(2,3,1,1,0,0.01,1000)
